# %%
# Importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Data Analytics Course\My Portfolio Projects\Project3-World Happiness Records in Python\2019_cleaned.csv")
df
# Out:
#      Overall_Rank         Country_or_Region  Happiness_Score  \
# 0               1                   Finland            7.769
# 1               2                   Denmark            7.600
# 2               3                    Norway            7.554
# 3               4                   Iceland            7.494
# 4               5               Netherlands            7.488
# ..            ...                       ...              ...
# 151           152                    Rwanda            3.334
# 152           153                  Tanzania            3.231
# 153           154               Afghanistan            3.203
# 154           155  Central African Republic            3.083
# 155           156               South Sudan            2.853
#
#      Economy(GDP_per_Capita)  Social_Support  Healthy_Life_Expectancy  \
# 0                      1.340           1.587                    0.986
# 1                      1.383           1.573                    0.996
# ...

# %%
print(df.head())
print(df.info())
print(df.describe())
# Out:
#    Overall_Rank Country_or_Region  Happiness_Score  Economy(GDP_per_Capita)  \
# 0             1           Finland            7.769                    1.340
# 1             2           Denmark            7.600                    1.383
# 2             3            Norway            7.554                    1.488
# 3             4           Iceland            7.494                    1.380
# 4             5       Netherlands            7.488                    1.396
#
#    Social_Support  Healthy_Life_Expectancy  Freedom  Generosity  \
# 0           1.587                    0.986    0.596       0.153
# 1           1.573                    0.996    0.592       0.252
# 2           1.582                    1.028    0.603       0.271
# 3           1.624                    1.026    0.591       0.354
# 4           1.522                    0.999    0.557       0.322
#
#    Perceptions_of_Corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# ...

# %%
# Top 10 Happiest Countries in 2019

top10 = df.sort_values('Happiness_Score', ascending=False).head(10)
sns.barplot(x='Happiness_Score', y='Country_or_Region', data=top10)
plt.title('Top 10 Happiest Countries (2019)')
plt.show()

# %%
# Which factors most strongly correlate with happiness?
numeric_df = df.select_dtypes(include=['number'])
corr_happiness = numeric_df.corr()['Happiness_Score'].drop(['Happiness_Score'], errors='ignore')

plt.figure(figsize=(8, 5))
sns.heatmap(corr_happiness.to_frame(), annot=True, cmap='coolwarm', cbar=False)
plt.title('Happiness Correlates')
plt.show()

# %%
# The Relationship Between Happiness and Its Strongest Correlate
sns.scatterplot(x='Economy(GDP_per_Capita)', y='Happiness_Score', data=df)
plt.title('Economy vs. Happiness Score')
plt.show()

# %%
# The Relationship Between Happiness and Its Weakest Correlate
sns.scatterplot(x='Generosity', y='Happiness_Score', data=df)
plt.title('Generosity vs. Happiness Score')
plt.show()

# %%
all_sheets = pd.read_excel(r"D:\Data Analytics Course\My Portfolio Projects\Project3-World Happiness Records in Python\World Happiness Report-cleaned dataset.xlsx",
    sheet_name=None)
df2 = pd.concat(all_sheets, ignore_index=False)
df2.reset_index(inplace=True)
df2.rename(columns={'level_0': 'Year'}, inplace=True)
df2.drop(columns=['level_1'], inplace=True)
df2
# Out:
#      Year                   Country  Happiness_Rank  Happiness_Score  \
# 0    2015               Switzerland               1            7.587
# 1    2015                   Iceland               2            7.561
# 2    2015                   Denmark               3            7.527
# 3    2015                    Norway               4            7.522
# 4    2015                    Canada               5            7.427
# ..    ...                       ...             ...              ...
# 777  2019                    Rwanda             152            3.334
# 778  2019                  Tanzania             153            3.231
# 779  2019               Afghanistan             154            3.203
# 780  2019  Central African Republic             155            3.083
# 781  2019               South Sudan             156            2.853
#
#      Economy(GDP_per_Capita)  Social_Support  Health_(Life_Expectancy)  \
# ...

# %%
# Average Happiness per Year

avg_year = df2.groupby('Year')['Happiness_Score'].mean().reset_index()
avg_year
# Out:
#    Year  Happiness_Score
# 0  2015         5.375734
# 1  2016         5.382185
# 2  2017         5.354019
# 3  2018         5.375917
# 4  2019         5.407096

# %%
# Average Happiness per Year Visualization

avg_year = df2.groupby('Year')['Happiness_Score'].mean().reset_index()
sns.lineplot(x='Year', y='Happiness_Score', data=avg_year)
plt.title('Average Global Happiness Over Time')
plt.show()

# %%
# Iran Happiness Report

Iran = df2[df2['Country'] == 'Iran']
Iran = Iran.reset_index(drop=True)
Iran
# Out:
#    Year Country  Happiness_Rank  Happiness_Score  Economy(GDP_per_Capita)  \
# 0  2015    Iran             110            4.686                 1.008800
# 1  2016    Iran             105            4.813                 1.117580
# 2  2017    Iran             108            4.692                 1.156873
# 3  2018    Iran             106            4.707                 1.059000
# 4  2019    Iran             117            4.548                 1.100000
#
#    Social_Support  Health_(Life_Expectancy)   Freedom  \
# 0        0.544470                  0.698050  0.300330
# 1        0.388570                  0.642320  0.225440
# 2        0.711551                  0.639333  0.249323
# 3        0.771000                  0.691000  0.459000
# 4        0.842000                  0.785000  0.305000
#
#    Perception_of_Corruption  Generosity
# 0                  0.058630    0.380860
# 1                  0.055700    0.385380
# 2                  0.048761    0.387243
# ...

# %%
factors = ['Happiness_Score', 'Economy(GDP_per_Capita)', 'Social_Support', 'Health_(Life_Expectancy)', 'Freedom', 'Perception_of_Corruption', 'Generosity']

# %%
melted = pd.melt(
    Iran,
    id_vars='Year',
    value_vars=factors,
    var_name='Factors',
    value_name='Scores'
)

plt.figure(figsize=(10, 6))
sns.lineplot(data=melted, x='Year', y='Scores', hue='Factors', marker='o')
plt.title('Trends Across Years in Iran')
plt.xlabel('Year')
plt.ylabel('Scores')
plt.grid(False)
plt.show()
